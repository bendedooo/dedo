# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import functools
import math
import scipy
from scipy.integrate import solve_ivp
from scipy.stats import norm

# Some useful utilities
from mcmc_utils_and_plot import scatter_matrix, build_cov_mat, lognormpdf, plot_bivariate_gauss, eval_func_on_grid

def compose(*functions):
    "Compose a list of functions"
    return functools.reduce(lambda f, g: lambda x: f(g(x)), functions, lambda x: x)

# %%
S0 = 900
I0 = 100
R0 = 0
x0 = [S0, I0, R0]

beta = 0.02
r = 0.6
delta = 0.15

N = 1000

t_span = np.linspace(0,6,61)

theta_vals = np.array([0.02, 0.6, 0.15])

def SIRmodel_init(t, x):
    S, I, R = x
    beta, r, delta = theta_vals
    return [delta*N-delta*S-beta*I*S, beta*I*S-(r+delta)*I, r*I - delta*R]
    
sol = scipy.integrate.solve_ivp(SIRmodel_init, [0, 6], x0, t_eval = t_span)

S=sol.y[0,:]
I=sol.y[1,:]
R=sol.y[2,:]

sigma = 50

Inoise=I
for ii in range(len(S)):
    Inoise[ii] = I[ii]+sigma*np.random.randn(1)

plt.plot(sol.t,Inoise)

# %%
def logmultivargaussianPDF(x,y,cov):
        logpdf = np.log(np.exp(-0.5*np.dot((x-y).T,np.dot(np.linalg.inv(cov),(x-y))))*1/(np.sqrt((2*np.pi)**2*np.linalg.det(cov)))) 
        return logpdf

# %%
class DelayedRejectionAdaptiveMetropolis:

    def __init__(self, logpdf, cov, k0=1000, freq=10, sd=None, max_samples=10000, eps=1e-7):
        """The class constructor, parameters are documented below"""
        self.logpdf = logpdf # callable (param) -> logpdf defining the logpdf
        self.cov = cov # initial covariance
        self.cov_chol = np.linalg.cholesky(cov) # sqrt of the covariance
        self.dim = cov.shape[0] # number of parameters
        self.k0 = k0 # time to start adapting
        self.freq = freq # frequency of covariance updates (should be an integer > 0)
        if sd == None:
            self.sd = (2.4**2) / self.dim
        else:
            self.sd = sd # scale for the covariance                    
        self.max_samples = max_samples # maximum number of samples
        self.eps = eps # nugget for ensuring positive definite
        self.num_samples = 0 # number of samples generated
        self.samples = np.zeros((max_samples, self.dim)) # store the samples
        self.logpdf_vals = np.zeros((max_samples))
       
    def sample(self, initial_sample, num_samples):
   
        assert num_samples <= self.max_samples, "Requesting more samples than space is allocated for"
       
        self.samples[0, :] = initial_sample
        self.logpdf_vals[0] = self.logpdf(initial_sample)
       
        accept = 0
        
        self.sample_mean = initial_sample
        for ii in range(1, num_samples):
           
            # propose
            y = self.samples[ii-1, :] + np.dot(self.cov_chol, np.random.randn(self.dim))
            y_logpdf = self.logpdf(y)
           
            # compute accept-reject probability, using the fact that we have a symmetric proposal
            a = np.exp(y_logpdf - self.logpdf_vals[ii-1])
            a = min(a, 1)
   
            u = np.random.rand()
           
            if u < a: #accept
                self.samples[ii, :] = y
                self.logpdf_vals[ii] = y_logpdf
                accept += 1
            else:
                # propose
                chollev2 = np.linalg.cholesky(0.5*self.cov) # sqrt of the covariance
                y2 = self.samples[ii-1, :] + np.dot(chollev2, np.random.randn(self.dim))
                y_logpdf2 = self.logpdf(y2)
                
                a1y2y1 = np.exp(y_logpdf-y_logpdf2)
                a1xy1 = np.exp(y_logpdf - self.logpdf_vals[ii-1])
                
                qterm1 = logmultivargaussianPDF(y,y2,self.cov)
                qterm2 = logmultivargaussianPDF(y,self.samples[ii-1, :],self.cov)
                
                a2 = np.exp((y_logpdf2+np.log(1-a1y2y1))-(self.logpdf_vals[ii-1]+np.log(1-a1xy1)))
                a2 = min(a2,1)
                
                u2 = np.random.rand()

                if u2 < a2: # accept
                    self.samples[ii, :] = y2
                    self.logpdf_vals[ii] = y_logpdf2
                    accept += 1
                else:
                    self.samples[ii, :] = self.samples[ii-1, :]
                    self.logpdf_vals[ii] = self.logpdf_vals[ii-1]
                    
            if ii > self.k0 and ii % self.freq:
                
                sample_mean_new = (1/(ii+1))*self.samples[ii, :] + (ii/(ii+1))*self.sample_mean
               
                update_term = self.eps*np.eye(self.dim) + ii*np.dot(self.sample_mean,self.sample_mean) - (ii+1)*np.dot(sample_mean_new,sample_mean_new) + np.dot(self.samples[ii, :],self.samples[ii, :])
                self.cov = (ii-1)*self.cov/ii + self.sd*update_term/ii
               
                self.sample_mean = sample_mean_new
                self.chol_cov = np.linalg.cholesky(self.cov)
               
            self.num_samples += 1
               
            if ii % 10 == 0:
                print(f"Finished sample {ii}, acceptance ratio = {accept / self.num_samples}")
               
        return self.samples

# %%
def logpdf_SIR(theta):

    def SIRmodel(t, x):
        S, I, R = x
        N=1000
        beta, r, delta = theta
        SIRout = [delta*N-delta*S-beta*I*S, beta*I*S-(r+delta)*I, r*I - delta*R]
        return SIRout
    
    sol = scipy.integrate.solve_ivp(SIRmodel, [0, 6], [900, 100, 0], t_eval = np.linspace(0,6,61))
    
    ypdf = np.zeros(len(sol.y[1,:]))
    tpdf = np.zeros(3)
    
    if theta[0] >= 0 and theta[1] >= 0 and theta[2] >= 0:
        for ii in range(len(sol.y[1,:])):
             ypdf[ii] = np.log(norm.pdf(sol.y[1,ii],Inoise[ii], 50))
             #ypdf[ii] = np.log((1/(50*np.sqrt(2*np.pi)))*np.exp((-1/2)*np.square((Inoise[ii] - sol.y[1,ii])/50)))
            
        for jj in range(3):
             tpdf[jj] = np.log(norm.pdf(theta[jj],0,1))
        
        #print(ypdf)
        return np.sum(tpdf) + np.sum(ypdf)
    else:
        return -np.inf

# %%
def laplace_approx(initial_guess, logpost):
    """ Perform the laplace approximation
    
    Inputs
    -------
    initial_guess: (p, ) array of parameter guesses
    logpost: callable (p) to a scalar, denoting the posterior
    
    Output
    ------
    map_point: (p, )
    covariance: inverse hessian    
    """
    
    def neglogpost(params):
        return -logpost(params)
    
    # Gradient free method to obtain close to optimum
    res = scipy.optimize.minimize(neglogpost, initial_guess, method='Nelder-Mead')
    
    # Gradient based method to approximate hessian
    res = scipy.optimize.minimize(neglogpost, res.x)
    
    map_point = res.x
    cov_approx = res.hess_inv
    return map_point, cov_approx

# %%
num_samples = 5000
cov_initial = np.diag(np.array([2e-4, 1e-3, 1e-3]))
theta_initial = np.array([0.02, 0.6, 0.15])
dram = DelayedRejectionAdaptiveMetropolis(logpdf_SIR, cov_initial, freq=5, k0=800, sd=2.4**2/2, eps=1e-6, max_samples=num_samples)
samples = dram.sample(theta_initial,num_samples)
# Out:
# C:\Users\jacki\AppData\Local\Temp/ipykernel_1940/302786802.py:59: RuntimeWarning: invalid value encountered in log
#   a2 = np.exp((y_logpdf2+np.log(1-a1y2y1))-(self.logpdf_vals[ii-1]+np.log(1-a1xy1)))
# Finished sample 10, acceptance ratio = 0.1
# C:\Users\jacki\AppData\Local\Temp/ipykernel_1940/302786802.py:53: RuntimeWarning: overflow encountered in exp
#   a1y2y1 = np.exp(y_logpdf-y_logpdf2)
# Finished sample 20, acceptance ratio = 0.1
# Finished sample 30, acceptance ratio = 0.06666666666666667
# Finished sample 40, acceptance ratio = 0.05
# Finished sample 50, acceptance ratio = 0.04
# Finished sample 60, acceptance ratio = 0.05
# Finished sample 70, acceptance ratio = 0.05714285714285714
# Finished sample 80, acceptance ratio = 0.0625
# Finished sample 90, acceptance ratio = 0.07777777777777778
# Finished sample 100, acceptance ratio = 0.09
# Finished sample 110, acceptance ratio = 0.09090909090909091
# Finished sample 120, acceptance ratio = 0.1
# Finished sample 130, acceptance ratio = 0.1
# Finished sample 140, acceptance ratio = 0.1
# Finished sample 150, acceptance ratio = 0.09333333333333334
# Finished sample 160, acceptance ratio = 0.09375
# Finished sample 170, acceptance ratio = 0.1
# Finished sample 180, acceptance ratio = 0.09444444444444444
# Finished sample 190, acceptance ratio = 0.09473684210526316
# Finished sample 200, acceptance ratio = 0.095
# Finished sample 210, acceptance ratio = 0.09523809523809523
# Finished sample 220, acceptance ratio = 0.09545454545454546
# Finished sample 230, acceptance ratio = 0.1
# Finished sample 240, acceptance ratio = 0.09583333333333334
# Finished sample 250, acceptance ratio = 0.1
# Finished sample 260, acceptance ratio = 0.1076923076923077
# Finished sample 270, acceptance ratio = 0.10740740740740741
# Finished sample 280, acceptance ratio = 0.10357142857142858
# Finished sample 290, acceptance ratio = 0.1
# Finished sample 300, acceptance ratio = 0.09666666666666666
# Finished sample 310, acceptance ratio = 0.1032258064516129
# Finished sample 320, acceptance ratio = 0.103125
# Finished sample 330, acceptance ratio = 0.10303030303030303
# Finished sample 340, acceptance ratio = 0.1
# Finished sample 350, acceptance ratio = 0.1
# Finished sample 360, acceptance ratio = 0.1
# Finished sample 370, acceptance ratio = 0.0972972972972973
# Finished sample 380, acceptance ratio = 0.09736842105263158
# Finished sample 390, acceptance ratio = 0.09743589743589744
# Finished sample 400, acceptance ratio = 0.0975
# Finished sample 410, acceptance ratio = 0.1
# Finished sample 420, acceptance ratio = 0.09761904761904762
# Finished sample 430, acceptance ratio = 0.09534883720930233
# Finished sample 440, acceptance ratio = 0.09772727272727273
# Finished sample 450, acceptance ratio = 0.09777777777777778
# Finished sample 460, acceptance ratio = 0.09782608695652174
# Finished sample 470, acceptance ratio = 0.09787234042553192
# Finished sample 480, acceptance ratio = 0.1
# Finished sample 490, acceptance ratio = 0.10408163265306122
# Finished sample 500, acceptance ratio = 0.106
# Finished sample 510, acceptance ratio = 0.10980392156862745
# Finished sample 520, acceptance ratio = 0.11153846153846154
# Finished sample 530, acceptance ratio = 0.11509433962264151
# Finished sample 540, acceptance ratio = 0.11296296296296296
# Finished sample 550, acceptance ratio = 0.11090909090909092
# Finished sample 560, acceptance ratio = 0.11607142857142858
# Finished sample 570, acceptance ratio = 0.11754385964912281
# Finished sample 580, acceptance ratio = 0.11724137931034483
# Finished sample 590, acceptance ratio = 0.11694915254237288
# Finished sample 600, acceptance ratio = 0.11666666666666667
# Finished sample 610, acceptance ratio = 0.11639344262295082
# Finished sample 620, acceptance ratio = 0.11612903225806452
# Finished sample 630, acceptance ratio = 0.11746031746031746
# Finished sample 640, acceptance ratio = 0.115625
# Finished sample 650, acceptance ratio = 0.11384615384615385
# Finished sample 660, acceptance ratio = 0.11212121212121212
# Finished sample 670, acceptance ratio = 0.11044776119402985
# Finished sample 680, acceptance ratio = 0.11029411764705882
# Finished sample 690, acceptance ratio = 0.10869565217391304
# Finished sample 700, acceptance ratio = 0.11285714285714285
# Finished sample 710, acceptance ratio = 0.11267605633802817
# Finished sample 720, acceptance ratio = 0.11527777777777778
# Finished sample 730, acceptance ratio = 0.11643835616438356
# Finished sample 740, acceptance ratio = 0.11756756756756757
# Finished sample 750, acceptance ratio = 0.11866666666666667
# Finished sample 760, acceptance ratio = 0.11710526315789474
# Finished sample 770, acceptance ratio = 0.11818181818181818
# Finished sample 780, acceptance ratio = 0.11794871794871795
# Finished sample 790, acceptance ratio = 0.11772151898734177
# Finished sample 800, acceptance ratio = 0.11625
# Finished sample 810, acceptance ratio = 0.11604938271604938
# Finished sample 820, acceptance ratio = 0.11463414634146342
# Finished sample 830, acceptance ratio = 0.11325301204819277
# Finished sample 840, acceptance ratio = 0.11428571428571428
# Finished sample 850, acceptance ratio = 0.11764705882352941
# Finished sample 860, acceptance ratio = 0.11744186046511627
# Finished sample 870, acceptance ratio = 0.11724137931034483
# Finished sample 880, acceptance ratio = 0.11818181818181818
# Finished sample 890, acceptance ratio = 0.11797752808988764
# Finished sample 900, acceptance ratio = 0.11666666666666667
# Finished sample 910, acceptance ratio = 0.11648351648351649
# Finished sample 920, acceptance ratio = 0.11521739130434783
# Finished sample 930, acceptance ratio = 0.11397849462365592
# Finished sample 940, acceptance ratio = 0.11382978723404255
# Finished sample 950, acceptance ratio = 0.11368421052631579
# Finished sample 960, acceptance ratio = 0.1125
# Finished sample 970, acceptance ratio = 0.1154639175257732
# Finished sample 980, acceptance ratio = 0.11428571428571428
# Finished sample 990, acceptance ratio = 0.11616161616161616
# Finished sample 1000, acceptance ratio = 0.117
# Finished sample 1010, acceptance ratio = 0.11584158415841585
# Finished sample 1020, acceptance ratio = 0.11568627450980393
# Finished sample 1030, acceptance ratio = 0.1145631067961165
# Finished sample 1040, acceptance ratio = 0.11442307692307692
# Finished sample 1050, acceptance ratio = 0.11428571428571428
# Finished sample 1060, acceptance ratio = 0.11320754716981132
# Finished sample 1070, acceptance ratio = 0.1130841121495327
# Finished sample 1080, acceptance ratio = 0.11296296296296296
# Finished sample 1090, acceptance ratio = 0.11376146788990826
# Finished sample 1100, acceptance ratio = 0.11272727272727273
# Finished sample 1110, acceptance ratio = 0.11171171171171171
# Finished sample 1120, acceptance ratio = 0.11160714285714286
# Finished sample 1130, acceptance ratio = 0.11150442477876106
# Finished sample 1140, acceptance ratio = 0.11052631578947368
# Finished sample 1150, acceptance ratio = 0.11130434782608696
# Finished sample 1160, acceptance ratio = 0.1103448275862069
# Finished sample 1170, acceptance ratio = 0.11196581196581197
# Finished sample 1180, acceptance ratio = 0.11186440677966102
# Finished sample 1190, acceptance ratio = 0.11176470588235295
# Finished sample 1200, acceptance ratio = 0.11333333333333333
# Finished sample 1210, acceptance ratio = 0.11239669421487604
# Finished sample 1220, acceptance ratio = 0.11311475409836065
# Finished sample 1230, acceptance ratio = 0.11463414634146342
# Finished sample 1240, acceptance ratio = 0.11451612903225807
# Finished sample 1250, acceptance ratio = 0.1136
# Finished sample 1260, acceptance ratio = 0.11507936507936507
# Finished sample 1270, acceptance ratio = 0.115748031496063
# Finished sample 1280, acceptance ratio = 0.11484375
# Finished sample 1290, acceptance ratio = 0.11472868217054263
# Finished sample 1300, acceptance ratio = 0.11461538461538462
# Finished sample 1310, acceptance ratio = 0.11374045801526718
# Finished sample 1320, acceptance ratio = 0.11363636363636363
# Finished sample 1330, acceptance ratio = 0.11428571428571428
# Finished sample 1340, acceptance ratio = 0.11417910447761194
# Finished sample 1350, acceptance ratio = 0.11407407407407408
# Finished sample 1360, acceptance ratio = 0.11397058823529412
# Finished sample 1370, acceptance ratio = 0.11313868613138686
# Finished sample 1380, acceptance ratio = 0.11231884057971014
# Finished sample 1390, acceptance ratio = 0.11151079136690648
# Finished sample 1400, acceptance ratio = 0.11142857142857143
# Finished sample 1410, acceptance ratio = 0.11134751773049645
# Finished sample 1420, acceptance ratio = 0.1119718309859155
# Finished sample 1430, acceptance ratio = 0.11118881118881119
# Finished sample 1440, acceptance ratio = 0.11041666666666666
# Finished sample 1450, acceptance ratio = 0.1096551724137931
# Finished sample 1460, acceptance ratio = 0.1095890410958904
# Finished sample 1470, acceptance ratio = 0.10884353741496598
# Finished sample 1480, acceptance ratio = 0.10878378378378378
# Finished sample 1490, acceptance ratio = 0.1087248322147651
# Finished sample 1500, acceptance ratio = 0.10866666666666666
# Finished sample 1510, acceptance ratio = 0.10860927152317881
# Finished sample 1520, acceptance ratio = 0.10789473684210527
# Finished sample 1530, acceptance ratio = 0.10784313725490197
# Finished sample 1540, acceptance ratio = 0.10714285714285714
# Finished sample 1550, acceptance ratio = 0.10709677419354839
# Finished sample 1560, acceptance ratio = 0.1064102564102564
# Finished sample 1570, acceptance ratio = 0.10573248407643313
# Finished sample 1580, acceptance ratio = 0.10506329113924051
# Finished sample 1590, acceptance ratio = 0.10503144654088051
# Finished sample 1600, acceptance ratio = 0.105
# Finished sample 1610, acceptance ratio = 0.10559006211180125
# Finished sample 1620, acceptance ratio = 0.10555555555555556
# Finished sample 1630, acceptance ratio = 0.1049079754601227
# Finished sample 1640, acceptance ratio = 0.10548780487804878
# Finished sample 1650, acceptance ratio = 0.10484848484848484
# Finished sample 1660, acceptance ratio = 0.10481927710843374
# Finished sample 1670, acceptance ratio = 0.10538922155688622
# Finished sample 1680, acceptance ratio = 0.10476190476190476
# Finished sample 1690, acceptance ratio = 0.10473372781065089
# Finished sample 1700, acceptance ratio = 0.10411764705882352
# Finished sample 1710, acceptance ratio = 0.10350877192982456
# Finished sample 1720, acceptance ratio = 0.10290697674418604
# Finished sample 1730, acceptance ratio = 0.10289017341040463
# Finished sample 1740, acceptance ratio = 0.10229885057471265
# Finished sample 1750, acceptance ratio = 0.10285714285714286
# Finished sample 1760, acceptance ratio = 0.1028409090909091
# Finished sample 1770, acceptance ratio = 0.10282485875706214
# Finished sample 1780, acceptance ratio = 0.10224719101123596
# Finished sample 1790, acceptance ratio = 0.10167597765363129
# Finished sample 1800, acceptance ratio = 0.10166666666666667
# Finished sample 1810, acceptance ratio = 0.10220994475138122
# Finished sample 1820, acceptance ratio = 0.1021978021978022
# Finished sample 1830, acceptance ratio = 0.10218579234972677
# Finished sample 1840, acceptance ratio = 0.10163043478260869
# Finished sample 1850, acceptance ratio = 0.10108108108108108
# Finished sample 1860, acceptance ratio = 0.1010752688172043
# Finished sample 1870, acceptance ratio = 0.10053475935828877
# Finished sample 1880, acceptance ratio = 0.1
# Finished sample 1890, acceptance ratio = 0.09947089947089947
# Finished sample 1900, acceptance ratio = 0.09894736842105263
# Finished sample 1910, acceptance ratio = 0.09842931937172775
# Finished sample 1920, acceptance ratio = 0.09791666666666667
# Finished sample 1930, acceptance ratio = 0.09740932642487046
# Finished sample 1940, acceptance ratio = 0.09690721649484536
# Finished sample 1950, acceptance ratio = 0.09743589743589744
# Finished sample 1960, acceptance ratio = 0.09744897959183674
# Finished sample 1970, acceptance ratio = 0.09746192893401015
# Finished sample 1980, acceptance ratio = 0.09747474747474748
# Finished sample 1990, acceptance ratio = 0.09849246231155778
# Finished sample 2000, acceptance ratio = 0.0985
# Finished sample 2010, acceptance ratio = 0.09900497512437811
# Finished sample 2020, acceptance ratio = 0.09950495049504951
# Finished sample 2030, acceptance ratio = 0.09950738916256158
# Finished sample 2040, acceptance ratio = 0.09901960784313725
# Finished sample 2050, acceptance ratio = 0.09902439024390244
# Finished sample 2060, acceptance ratio = 0.09902912621359224
# Finished sample 2070, acceptance ratio = 0.09951690821256039
# Finished sample 2080, acceptance ratio = 0.09903846153846153
# Finished sample 2090, acceptance ratio = 0.09904306220095693
# Finished sample 2100, acceptance ratio = 0.09952380952380953
# Finished sample 2110, acceptance ratio = 0.0990521327014218
# Finished sample 2120, acceptance ratio = 0.09858490566037736
# Finished sample 2130, acceptance ratio = 0.09859154929577464
# Finished sample 2140, acceptance ratio = 0.0985981308411215
# Finished sample 2150, acceptance ratio = 0.09813953488372093
# Finished sample 2160, acceptance ratio = 0.09814814814814815
# Finished sample 2170, acceptance ratio = 0.09769585253456221
# Finished sample 2180, acceptance ratio = 0.0981651376146789
# Finished sample 2190, acceptance ratio = 0.09771689497716896
# Finished sample 2200, acceptance ratio = 0.09772727272727273
# Finished sample 2210, acceptance ratio = 0.09728506787330317
# Finished sample 2220, acceptance ratio = 0.0972972972972973
# Finished sample 2230, acceptance ratio = 0.0968609865470852
# Finished sample 2240, acceptance ratio = 0.096875
# Finished sample 2250, acceptance ratio = 0.09644444444444444
# Finished sample 2260, acceptance ratio = 0.09646017699115045
# Finished sample 2270, acceptance ratio = 0.0960352422907489
# Finished sample 2280, acceptance ratio = 0.0956140350877193
# Finished sample 2290, acceptance ratio = 0.09563318777292576
# Finished sample 2300, acceptance ratio = 0.09565217391304348
# Finished sample 2310, acceptance ratio = 0.09610389610389611
# Finished sample 2320, acceptance ratio = 0.09568965517241379
# Finished sample 2330, acceptance ratio = 0.09527896995708154
# Finished sample 2340, acceptance ratio = 0.0952991452991453
# Finished sample 2350, acceptance ratio = 0.09489361702127659
# Finished sample 2360, acceptance ratio = 0.09449152542372881
# Finished sample 2370, acceptance ratio = 0.09451476793248945
# Finished sample 2380, acceptance ratio = 0.09453781512605042
# Finished sample 2390, acceptance ratio = 0.09414225941422594
# Finished sample 2400, acceptance ratio = 0.09375
# Finished sample 2410, acceptance ratio = 0.09336099585062241
# Finished sample 2420, acceptance ratio = 0.09297520661157024
# Finished sample 2430, acceptance ratio = 0.09300411522633745
# Finished sample 2440, acceptance ratio = 0.09262295081967213
# Finished sample 2450, acceptance ratio = 0.0926530612244898
# Finished sample 2460, acceptance ratio = 0.09349593495934959
# Finished sample 2470, acceptance ratio = 0.09392712550607288
# Finished sample 2480, acceptance ratio = 0.0935483870967742
# Finished sample 2490, acceptance ratio = 0.09397590361445783
# Finished sample 2500, acceptance ratio = 0.0936
# Finished sample 2510, acceptance ratio = 0.09362549800796813
# Finished sample 2520, acceptance ratio = 0.09325396825396826
# Finished sample 2530, acceptance ratio = 0.0932806324110672
# Finished sample 2540, acceptance ratio = 0.09330708661417322
# Finished sample 2550, acceptance ratio = 0.09294117647058824
# Finished sample 2560, acceptance ratio = 0.09296875
# Finished sample 2570, acceptance ratio = 0.09299610894941635
# Finished sample 2580, acceptance ratio = 0.09263565891472868
# Finished sample 2590, acceptance ratio = 0.09227799227799227
# Finished sample 2600, acceptance ratio = 0.09230769230769231
# Finished sample 2610, acceptance ratio = 0.09233716475095785
# Finished sample 2620, acceptance ratio = 0.09236641221374046
# Finished sample 2630, acceptance ratio = 0.09277566539923954
# Finished sample 2640, acceptance ratio = 0.09242424242424242
# Finished sample 2650, acceptance ratio = 0.09245283018867924
# Finished sample 2660, acceptance ratio = 0.09210526315789473
# Finished sample 2670, acceptance ratio = 0.09213483146067415
# Finished sample 2680, acceptance ratio = 0.09179104477611941
# Finished sample 2690, acceptance ratio = 0.09219330855018587
# Finished sample 2700, acceptance ratio = 0.09185185185185185
# Finished sample 2710, acceptance ratio = 0.09151291512915129
# Finished sample 2720, acceptance ratio = 0.09154411764705882
# Finished sample 2730, acceptance ratio = 0.0912087912087912
# Finished sample 2740, acceptance ratio = 0.09124087591240876
# Finished sample 2750, acceptance ratio = 0.09090909090909091
# Finished sample 2760, acceptance ratio = 0.09130434782608696
# Finished sample 2770, acceptance ratio = 0.09169675090252707
# Finished sample 2780, acceptance ratio = 0.09136690647482014
# Finished sample 2790, acceptance ratio = 0.0910394265232975
# Finished sample 2800, acceptance ratio = 0.09071428571428572
# Finished sample 2810, acceptance ratio = 0.0911032028469751
# Finished sample 2820, acceptance ratio = 0.09113475177304965
# Finished sample 2830, acceptance ratio = 0.09081272084805654
# Finished sample 2840, acceptance ratio = 0.09119718309859155
# Finished sample 2850, acceptance ratio = 0.09087719298245614
# Finished sample 2860, acceptance ratio = 0.09090909090909091
# Finished sample 2870, acceptance ratio = 0.09094076655052265
# Finished sample 2880, acceptance ratio = 0.09097222222222222
# Finished sample 2890, acceptance ratio = 0.09065743944636678
# Finished sample 2900, acceptance ratio = 0.0906896551724138
# Finished sample 2910, acceptance ratio = 0.09072164948453608
# Finished sample 2920, acceptance ratio = 0.09041095890410959
# Finished sample 2930, acceptance ratio = 0.09078498293515358
# Finished sample 2940, acceptance ratio = 0.09115646258503401
# Finished sample 2950, acceptance ratio = 0.09118644067796611
# Finished sample 2960, acceptance ratio = 0.09087837837837838
# Finished sample 2970, acceptance ratio = 0.09057239057239057
# Finished sample 2980, acceptance ratio = 0.09026845637583893
# Finished sample 2990, acceptance ratio = 0.08996655518394649
# Finished sample 3000, acceptance ratio = 0.08966666666666667
# Finished sample 3010, acceptance ratio = 0.08970099667774087
# Finished sample 3020, acceptance ratio = 0.08940397350993377
# Finished sample 3030, acceptance ratio = 0.08943894389438944
# Finished sample 3040, acceptance ratio = 0.09046052631578948
# Finished sample 3050, acceptance ratio = 0.09049180327868853
# Finished sample 3060, acceptance ratio = 0.09019607843137255
# Finished sample 3070, acceptance ratio = 0.09022801302931596
# Finished sample 3080, acceptance ratio = 0.09090909090909091
# Finished sample 3090, acceptance ratio = 0.09061488673139159
# Finished sample 3100, acceptance ratio = 0.09064516129032259
# Finished sample 3110, acceptance ratio = 0.0909967845659164
# Finished sample 3120, acceptance ratio = 0.09134615384615384
# Finished sample 3130, acceptance ratio = 0.09105431309904154
# Finished sample 3140, acceptance ratio = 0.09171974522292993
# Finished sample 3150, acceptance ratio = 0.09142857142857143
# Finished sample 3160, acceptance ratio = 0.09113924050632911
# Finished sample 3170, acceptance ratio = 0.09179810725552051
# Finished sample 3180, acceptance ratio = 0.09182389937106918
# Finished sample 3190, acceptance ratio = 0.09153605015673981
# Finished sample 3200, acceptance ratio = 0.09125
# Finished sample 3210, acceptance ratio = 0.09158878504672897
# Finished sample 3220, acceptance ratio = 0.09130434782608696
# Finished sample 3230, acceptance ratio = 0.09102167182662539
# Finished sample 3240, acceptance ratio = 0.09074074074074075
# Finished sample 3250, acceptance ratio = 0.09046153846153847
# Finished sample 3260, acceptance ratio = 0.09049079754601227
# Finished sample 3270, acceptance ratio = 0.09021406727828746
# Finished sample 3280, acceptance ratio = 0.0899390243902439
# Finished sample 3290, acceptance ratio = 0.08966565349544073
# Finished sample 3300, acceptance ratio = 0.0893939393939394
# Finished sample 3310, acceptance ratio = 0.0891238670694864
# Finished sample 3320, acceptance ratio = 0.0891566265060241
# Finished sample 3330, acceptance ratio = 0.08888888888888889
# Finished sample 3340, acceptance ratio = 0.08892215568862276
# Finished sample 3350, acceptance ratio = 0.08895522388059701
# Finished sample 3360, acceptance ratio = 0.0886904761904762
# Finished sample 3370, acceptance ratio = 0.0887240356083086
# Finished sample 3380, acceptance ratio = 0.08846153846153847
# Finished sample 3390, acceptance ratio = 0.08849557522123894
# Finished sample 3400, acceptance ratio = 0.08823529411764706
# Finished sample 3410, acceptance ratio = 0.08826979472140763
# Finished sample 3420, acceptance ratio = 0.08859649122807017
# Finished sample 3430, acceptance ratio = 0.08862973760932945
# Finished sample 3440, acceptance ratio = 0.08866279069767442
# Finished sample 3450, acceptance ratio = 0.08840579710144927
# Finished sample 3460, acceptance ratio = 0.08815028901734104
# Finished sample 3470, acceptance ratio = 0.08818443804034583
# Finished sample 3480, acceptance ratio = 0.0882183908045977
# Finished sample 3490, acceptance ratio = 0.08796561604584527
# Finished sample 3500, acceptance ratio = 0.088
# Finished sample 3510, acceptance ratio = 0.08831908831908832
# Finished sample 3520, acceptance ratio = 0.08806818181818182
# Finished sample 3530, acceptance ratio = 0.08810198300283287
# Finished sample 3540, acceptance ratio = 0.08813559322033898
# Finished sample 3550, acceptance ratio = 0.08788732394366197
# Finished sample 3560, acceptance ratio = 0.08764044943820225
# Finished sample 3570, acceptance ratio = 0.0876750700280112
# Finished sample 3580, acceptance ratio = 0.08770949720670392
# Finished sample 3590, acceptance ratio = 0.08746518105849582
# Finished sample 3600, acceptance ratio = 0.08722222222222223
# Finished sample 3610, acceptance ratio = 0.08725761772853186
# Finished sample 3620, acceptance ratio = 0.08729281767955802
# Finished sample 3630, acceptance ratio = 0.08760330578512397
# Finished sample 3640, acceptance ratio = 0.08736263736263736
# Finished sample 3650, acceptance ratio = 0.08794520547945206
# Finished sample 3660, acceptance ratio = 0.08770491803278689
# Finished sample 3670, acceptance ratio = 0.08746594005449591
# Finished sample 3680, acceptance ratio = 0.0875
# Finished sample 3690, acceptance ratio = 0.08753387533875338
# Finished sample 3700, acceptance ratio = 0.0872972972972973
# Finished sample 3710, acceptance ratio = 0.08733153638814016
# Finished sample 3720, acceptance ratio = 0.08709677419354839
# Finished sample 3730, acceptance ratio = 0.08739946380697051
# Finished sample 3740, acceptance ratio = 0.0874331550802139
# Finished sample 3750, acceptance ratio = 0.08746666666666666
# Finished sample 3760, acceptance ratio = 0.08723404255319149
# Finished sample 3770, acceptance ratio = 0.08726790450928382
# Finished sample 3780, acceptance ratio = 0.08756613756613757
# Finished sample 3790, acceptance ratio = 0.08759894459102903
# Finished sample 3800, acceptance ratio = 0.08736842105263158
# Finished sample 3810, acceptance ratio = 0.08766404199475065
# Finished sample 3820, acceptance ratio = 0.08743455497382199
# Finished sample 3830, acceptance ratio = 0.08746736292428199
# Finished sample 3840, acceptance ratio = 0.08723958333333333
# Finished sample 3850, acceptance ratio = 0.08701298701298701
# Finished sample 3860, acceptance ratio = 0.08730569948186528
# Finished sample 3870, acceptance ratio = 0.08785529715762273
# Finished sample 3880, acceptance ratio = 0.08788659793814432
# Finished sample 3890, acceptance ratio = 0.08791773778920309
# Finished sample 3900, acceptance ratio = 0.0876923076923077
# Finished sample 3910, acceptance ratio = 0.08797953964194373
# Finished sample 3920, acceptance ratio = 0.08801020408163265
# Finished sample 3930, acceptance ratio = 0.08804071246819338
# Finished sample 3940, acceptance ratio = 0.0883248730964467
# Finished sample 3950, acceptance ratio = 0.08810126582278481
# Finished sample 3960, acceptance ratio = 0.08813131313131313
# Finished sample 3970, acceptance ratio = 0.08790931989924433
# Finished sample 3980, acceptance ratio = 0.08768844221105528
# Finished sample 3990, acceptance ratio = 0.08796992481203007
# Finished sample 4000, acceptance ratio = 0.08775
# Finished sample 4010, acceptance ratio = 0.08778054862842893
# Finished sample 4020, acceptance ratio = 0.08756218905472637
# Finished sample 4030, acceptance ratio = 0.08784119106699752
# Finished sample 4040, acceptance ratio = 0.08787128712871287
# Finished sample 4050, acceptance ratio = 0.08765432098765433
# Finished sample 4060, acceptance ratio = 0.0874384236453202
# Finished sample 4070, acceptance ratio = 0.08722358722358722
# Finished sample 4080, acceptance ratio = 0.08725490196078431
# Finished sample 4090, acceptance ratio = 0.08704156479217603
# Finished sample 4100, acceptance ratio = 0.08682926829268292
# Finished sample 4110, acceptance ratio = 0.08686131386861314
# Finished sample 4120, acceptance ratio = 0.08689320388349514
# Finished sample 4130, acceptance ratio = 0.08716707021791767
# Finished sample 4140, acceptance ratio = 0.08695652173913043
# Finished sample 4150, acceptance ratio = 0.08698795180722892
# Finished sample 4160, acceptance ratio = 0.08725961538461538
# Finished sample 4170, acceptance ratio = 0.08729016786570744
# Finished sample 4180, acceptance ratio = 0.08779904306220096
# Finished sample 4190, acceptance ratio = 0.08782816229116945
# Finished sample 4200, acceptance ratio = 0.08785714285714286
# Finished sample 4210, acceptance ratio = 0.08764845605700712
# Finished sample 4220, acceptance ratio = 0.08767772511848342
# Finished sample 4230, acceptance ratio = 0.08770685579196218
# Finished sample 4240, acceptance ratio = 0.08773584905660377
# Finished sample 4250, acceptance ratio = 0.088
# Finished sample 4260, acceptance ratio = 0.0880281690140845
# Finished sample 4270, acceptance ratio = 0.08782201405152225
# Finished sample 4280, acceptance ratio = 0.08761682242990654
# Finished sample 4290, acceptance ratio = 0.08741258741258741
# Finished sample 4300, acceptance ratio = 0.08744186046511628
# Finished sample 4310, acceptance ratio = 0.08770301624129931
# Finished sample 4320, acceptance ratio = 0.0875
# Finished sample 4330, acceptance ratio = 0.08752886836027714
# Finished sample 4340, acceptance ratio = 0.08778801843317972
# Finished sample 4350, acceptance ratio = 0.08758620689655172
# Finished sample 4360, acceptance ratio = 0.08761467889908257
# Finished sample 4370, acceptance ratio = 0.0874141876430206
# Finished sample 4380, acceptance ratio = 0.08721461187214612
# Finished sample 4390, acceptance ratio = 0.08701594533029612
# Finished sample 4400, acceptance ratio = 0.08681818181818182
# Finished sample 4410, acceptance ratio = 0.08662131519274377
# Finished sample 4420, acceptance ratio = 0.08642533936651584
# Finished sample 4430, acceptance ratio = 0.08645598194130925
# Finished sample 4440, acceptance ratio = 0.08648648648648649
# Finished sample 4450, acceptance ratio = 0.08629213483146067
# Finished sample 4460, acceptance ratio = 0.08632286995515695
# Finished sample 4470, acceptance ratio = 0.08612975391498881
# Finished sample 4480, acceptance ratio = 0.08616071428571428
# Finished sample 4490, acceptance ratio = 0.08596881959910913
# Finished sample 4500, acceptance ratio = 0.086
# Finished sample 4510, acceptance ratio = 0.0860310421286031
# Finished sample 4520, acceptance ratio = 0.08584070796460178
# Finished sample 4530, acceptance ratio = 0.0858719646799117
# Finished sample 4540, acceptance ratio = 0.08612334801762114
# Finished sample 4550, acceptance ratio = 0.08593406593406594
# Finished sample 4560, acceptance ratio = 0.08574561403508772
# Finished sample 4570, acceptance ratio = 0.08577680525164114
# Finished sample 4580, acceptance ratio = 0.08580786026200873
# Finished sample 4590, acceptance ratio = 0.08562091503267974
# Finished sample 4600, acceptance ratio = 0.08543478260869565
# Finished sample 4610, acceptance ratio = 0.08524945770065076
# Finished sample 4620, acceptance ratio = 0.08528138528138528
# Finished sample 4630, acceptance ratio = 0.08552915766738661
# Finished sample 4640, acceptance ratio = 0.0855603448275862
# Finished sample 4650, acceptance ratio = 0.08559139784946236
# Finished sample 4660, acceptance ratio = 0.08562231759656652
# Finished sample 4670, acceptance ratio = 0.08565310492505353
# Finished sample 4680, acceptance ratio = 0.08547008547008547
# Finished sample 4690, acceptance ratio = 0.08571428571428572
# Finished sample 4700, acceptance ratio = 0.08574468085106383
# Finished sample 4710, acceptance ratio = 0.08577494692144373
# Finished sample 4720, acceptance ratio = 0.08559322033898305
# Finished sample 4730, acceptance ratio = 0.08562367864693446
# Finished sample 4740, acceptance ratio = 0.08544303797468354
# Finished sample 4750, acceptance ratio = 0.08547368421052631
# Finished sample 4760, acceptance ratio = 0.08550420168067227
# Finished sample 4770, acceptance ratio = 0.08553459119496855
# Finished sample 4780, acceptance ratio = 0.08535564853556485
# Finished sample 4790, acceptance ratio = 0.08538622129436325
# Finished sample 4800, acceptance ratio = 0.08541666666666667
# Finished sample 4810, acceptance ratio = 0.08523908523908524
# Finished sample 4820, acceptance ratio = 0.08526970954356847
# Finished sample 4830, acceptance ratio = 0.08509316770186336
# Finished sample 4840, acceptance ratio = 0.08491735537190083
# Finished sample 4850, acceptance ratio = 0.0847422680412371
# Finished sample 4860, acceptance ratio = 0.08477366255144032
# Finished sample 4870, acceptance ratio = 0.08459958932238193
# Finished sample 4880, acceptance ratio = 0.08442622950819673
# Finished sample 4890, acceptance ratio = 0.08445807770961145
# Finished sample 4900, acceptance ratio = 0.08448979591836735
# Finished sample 4910, acceptance ratio = 0.08472505091649694
# Finished sample 4920, acceptance ratio = 0.08455284552845528
# Finished sample 4930, acceptance ratio = 0.08438133874239351
# Finished sample 4940, acceptance ratio = 0.08441295546558704
# Finished sample 4950, acceptance ratio = 0.08444444444444445
# Finished sample 4960, acceptance ratio = 0.0844758064516129
# Finished sample 4970, acceptance ratio = 0.08450704225352113
# Finished sample 4980, acceptance ratio = 0.08433734939759036
# Finished sample 4990, acceptance ratio = 0.0845691382765531

# %%
fig, axs, gs = scatter_matrix([samples], hist_plot=False, gamma=0.5)
fig.set_size_inches(15,15)
plt.subplots_adjust(left=0.01, right=0.99, wspace=0.2, hspace=0.2)

# %%
fig, axs = plt.subplots(2,1, figsize=(10,5))
axs[0].plot(samples[:, 0], '-k')
axs[0].set_ylabel(r'$x_1$', fontsize=14)
axs[1].plot(samples[:, 1], '-k')
axs[1].set_ylabel(r'$x_2$', fontsize=14)
axs[1].set_xlabel('Sample Number', fontsize=14)
axs[2].plot(samples[:, 1], '-k')
axs[2].set_ylabel(r'$x_2$', fontsize=14)
axs[2].set_xlabel('Sample Number', fontsize=14)
#axs[1].set_xlim([40000, 50000])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/4258945159.py in <module>
#       5 axs[1].set_ylabel(r'$x_2$', fontsize=14)
#       6 axs[1].set_xlabel('Sample Number', fontsize=14)
# ----> 7 axs[2].plot(samples[:, 1], '-k')
#       8 axs[2].set_ylabel(r'$x_2$', fontsize=14)
#       9 axs[2].set_xlabel('Sample Number', fontsize=14)
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
def autocorrelation(samples, maxlag=100, step=1):
    """Compute the correlation of a set of samples
    
    Inputs
    ------
    samples: (N, d)
    maxlag: maximum distance to compute the correlation for
    step: step between distances from 0 to maxlag for which to compute teh correlations
    """
    
    # Get the shapes
    ndim = samples.shape[1]
    nsamples = samples.shape[0]    
    
    # Compute the mean
    mean = np.mean(samples, axis=0)
    
    # Compute the denominator, which is variance
    denominator = np.zeros((ndim))
    for ii in range(nsamples):
        denominator = denominator + (samples[ii, :] - mean)**2
    
    lags = np.arange(0, maxlag, step)
    autos = np.zeros((len(lags), ndim))
    for zz, lag in enumerate(lags):
        autos[zz, :] = np.zeros((ndim))
        # compute the covariance between all samples *lag apart*
        for ii in range(nsamples - lag):
            autos[zz,:] = autos[zz, :] + (samples[ii,:]-mean)*(samples[ii + lag,:] -mean)
        autos[zz, :] = autos[zz, :]/denominator
    return lags, autos

# %%
maxlag=100
step=1
lags, autolag = autocorrelation(samples, maxlag=maxlag,step=step)
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(lags, autolag[:, 0],'-o')
axs[0].set_xlabel('lag')
axs[0].set_ylabel('autocorrelation dimension 1')
axs[1].plot(lags, autolag[:, 1],'-o')
axs[1].set_xlabel('lag')
axs[1].set_ylabel('autocorrelation dimension 2')
plt.show()

# %%
print(samples)
# Out:
# [[-7.79047155e-06 -1.00000793e+00]
#  [-2.95528267e-01 -1.64566116e+00]
#  [-1.78907512e-01 -1.24641336e+00]
#  ...
#  [-3.93225422e-01 -1.71795451e+00]
#  [ 3.90915265e-01 -8.04671116e-01]
#  [ 2.16188014e-01 -1.12417696e+00]]

# %%
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x29b5488c3d0>,
#  <matplotlib.lines.Line2D at 0x29b5488ca60>]
